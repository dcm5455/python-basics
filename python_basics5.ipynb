# %% [markdown]
# <a href="https://colab.research.google.com/github/dcm5455/python-basics/blob/main/python_basics5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# matplotlib

# %%
pip install matplotlib

# %% [markdown]
# line graph

# %%
from matplotlib import pyplot as plt
plt.plot([1,2,9],[1,3,9])
plt.title('Information')
plt.xlabel('X axix')
plt.ylabel('Y axixs')
plt.show()

# %%
x=[15,10,20]
y=[26,22,24]
x1=[4,5,6]
y1=[18,19,21]
plt.plot(x,y,'r',label='line',linewidth=5)
plt.plot(x1,y1,'g',label='line one',linewidth=9)
plt.legend()
plt.title('graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.grid()
plt.show()

# %%
from matplotlib import style

x = [5,8,10]

y = [12,16,6]

x2 = [6,9,11]

y2 = [6,15,7]

plt.plot(x,y,'g',label='line one', linewidth=5)

plt.plot(x2,y2,'c',label='line two',linewidth=5)

plt.title('Epic Info')

plt.ylabel('Y axis')

plt.xlabel('X axis')

plt.legend()

plt.grid(True,color='r')

plt.show()

# %% [markdown]
#  bar graph

# %%
from matplotlib import pyplot as plt

plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],
         
label="BMW",color='r',width=.1)

plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],

label="Audi", color='b',width=.5)

plt.legend()

plt.xlabel('Days')

plt.ylabel('Distance (kms)')

plt.title('Information')

plt.show()

# %% [markdown]
# histogram

# %%
import matplotlib.pyplot as plt

import numpy as np

population_age = [22,55,62,45,21,22,34,42,42,4,2,102,

                  95,85,55,110,120,70,65,55,111,42,42,42,42,

                  115,80 ,75,65,54,44,43,42,48,42,42,42]

bins = np.arange(1,200)

plt.hist(population_age,bins, histtype='step')

plt.xlabel('age groups')

plt.ylabel('Number of people')

plt.title('Histogram')

plt.show()

# %% [markdown]
# scatter plot

# %%
import matplotlib.pyplot as plt

x = [1,1.5,2,2.5,3,3.5,3.6]

y = [7.5,8,8.5,9,9.5,10,10.5]

x1=[8,8.5,9,9.5,10,10.5,11]

y1=[3,3.5,3.7,4,4.5,5,5.2]

plt.scatter(x,y, label='high income low saving',color='r')

plt.scatter(x1,y1,label='low income high savings',color='b')

plt.xlabel('saving*100')

plt.ylabel('income*1000')

plt.title('Scatter Plot')

plt.legend()

plt.show()

# %%
import numpy as np
plt.plot([1,9,3],[4,5,9],'ro-',label='line')
plt.plot([7,9,10],[8,6,9],'go-',label='line1')
plt.plot([5,9,3],[4,5,9],'bo-',label='line2')
plt.legend()
plt.show()

# %%
t=np.arange(0,5,.2)
plt.plot(t,t,'r--',t,t**2,'ro')

# %% [markdown]
# matplotlib-3D

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
iris=pd.read_csv('Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
for species,irissubset in iris.groupby('Species'):
 plt.scatter(irissubset['PetalLengthCm'],irissubset['PetalWidthCm'],label=species)
plt.legend()
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
for species,irissubset in iris.groupby('Species'):
 ax.scatter(irissubset['PetalLengthCm'],irissubset['PetalWidthCm'],irissubset['SepalLengthCm'],label=species)
ax.set_xlabel('PetalLengthCm')
ax.set_ylabel('PetalWidthCm')
ax.set_zlabel('SepalLengthCm')
plt.legend()
plt.show()

# %% [markdown]
# area plot

# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5]

sleeping =[7,8,6,11,7]

eating = [2,3,4,3,2]

working =[7,8,7,2,2]

playing = [8,5,7,8,13]

plt.plot([],[],color='m', label='Sleeping', linewidth=5)

plt.plot([],[],color='c', label='Eating', linewidth=5)

#plt.plot([],[],color='r', label='Working', linewidth=5)

#plt.plot([],[],color='k', label='Playing', linewidth=5)

plt.stackplot(days, sleeping,eating,working,playing,

              colors=['m','c','r','k'])

plt.xlabel('x')

plt.ylabel('y')

plt.title('Stack Plot')
# Out:
# Text(0.5, 1.0, 'Stack Plot')

# %% [markdown]
# pie-chart

# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5]

slices = [12,0.9,1,13]

activities = ['sleeping','eating','working','playing']

cols = ['b','g','r','y']

plt.pie(slices,

  labels=activities,

  colors=cols,

  startangle=180  )

plt.title('Pie Plot')

plt.show()

# %% [markdown]
# multiple plots

# %%
import numpy as np

import matplotlib.pyplot as plt

def f(t):

    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)

t2 = np.arange(0.0, 5.0, 0.02)

plt.subplot(211)  #no of plots, row wise or column wise, 1 2 plot

plt.plot(t1, f(t1), 'bo', t2, f(t2))

plt.subplot(212)

plt.plot(t2, np.cos(2*np.pi*t2))

plt.show()
